# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers = ["kafka:9092"],
    value_serializer = lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101,102,103,104,105]

print("starting transaction producer...")

for i in range(100):
    tx_data = {
        "tx_id":i,
        "userId": random.choice(user_ids),
        "amount": random.uniform(100.0,15000.0),
        "timestamp":time.time()
    }
    producer.send('fraud-detection',value=tx_data)
    print(f"Sent: {tx_data}")
    time.sleep(2)
# Out:
# starting transaction producer...
# Sent: {'tx_id': 0, 'userId': 102, 'amount': 12972.049562108652, 'timestamp': 1781846702.5381725}
# Sent: {'tx_id': 1, 'userId': 102, 'amount': 13319.963836242348, 'timestamp': 1781846704.6326568}
# Sent: {'tx_id': 2, 'userId': 105, 'amount': 9908.74247875599, 'timestamp': 1781846706.6351185}
# Sent: {'tx_id': 3, 'userId': 104, 'amount': 5578.614309857006, 'timestamp': 1781846708.6362803}
# Sent: {'tx_id': 4, 'userId': 101, 'amount': 2903.6227252980298, 'timestamp': 1781846710.6381102}
# Sent: {'tx_id': 5, 'userId': 103, 'amount': 10372.983819295747, 'timestamp': 1781846712.6391602}
# Sent: {'tx_id': 6, 'userId': 104, 'amount': 7298.005638111131, 'timestamp': 1781846714.6409369}
# Sent: {'tx_id': 7, 'userId': 105, 'amount': 6919.496982024924, 'timestamp': 1781846716.642345}
# Sent: {'tx_id': 8, 'userId': 101, 'amount': 2134.295724039085, 'timestamp': 1781846718.6434994}
# Sent: {'tx_id': 9, 'userId': 103, 'amount': 1408.8109546056946, 'timestamp': 1781846720.645938}
# Sent: {'tx_id': 10, 'userId': 101, 'amount': 6529.054383842386, 'timestamp': 1781846722.6486194}
# Sent: {'tx_id': 11, 'userId': 105, 'amount': 3691.026522182728, 'timestamp': 1781846724.6496842}
# Sent: {'tx_id': 12, 'userId': 102, 'amount': 2664.5705330883975, 'timestamp': 1781846726.6507573}
# Sent: {'tx_id': 13, 'userId': 103, 'amount': 14972.672215376273, 'timestamp': 1781846728.6522307}
# Sent: {'tx_id': 14, 'userId': 105, 'amount': 12990.694223494842, 'timestamp': 1781846730.6532042}
# Sent: {'tx_id': 15, 'userId': 102, 'amount': 9205.464095801735, 'timestamp': 1781846732.6511464}
# Sent: {'tx_id': 16, 'userId': 101, 'amount': 13445.675213019555, 'timestamp': 1781846734.6523173}
# Sent: {'tx_id': 17, 'userId': 104, 'amount': 8841.179520866332, 'timestamp': 1781846736.653315}
# Sent: {'tx_id': 18, 'userId': 103, 'amount': 2612.4286893425306, 'timestamp': 1781846738.654294}
# Sent: {'tx_id': 19, 'userId': 102, 'amount': 6587.577664001238, 'timestamp': 1781846740.6552978}
# Sent: {'tx_id': 20, 'userId': 101, 'amount': 10234.385976755113, 'timestamp': 1781846742.6565053}
# Sent: {'tx_id': 21, 'userId': 101, 'amount': 3803.993820217165, 'timestamp': 1781846744.6575074}
# Sent: {'tx_id': 22, 'userId': 101, 'amount': 12139.285493493135, 'timestamp': 1781846746.658463}
# Sent: {'tx_id': 23, 'userId': 102, 'amount': 1971.217297810104, 'timestamp': 1781846748.663298}
# Sent: {'tx_id': 24, 'userId': 102, 'amount': 6789.501536283988, 'timestamp': 1781846750.6652477}
# Sent: {'tx_id': 25, 'userId': 105, 'amount': 7496.471479128669, 'timestamp': 1781846752.6662085}
# Sent: {'tx_id': 26, 'userId': 101, 'amount': 5508.344396582551, 'timestamp': 1781846754.6670883}
# Sent: {'tx_id': 27, 'userId': 105, 'amount': 6932.183771956402, 'timestamp': 1781846756.668295}
# Sent: {'tx_id': 28, 'userId': 103, 'amount': 2439.942979049818, 'timestamp': 1781846758.6694038}
# Sent: {'tx_id': 29, 'userId': 104, 'amount': 6885.743374910914, 'timestamp': 1781846760.6702037}
# Sent: {'tx_id': 30, 'userId': 105, 'amount': 14443.694375158097, 'timestamp': 1781846762.6678486}
# Sent: {'tx_id': 31, 'userId': 102, 'amount': 2386.071259035051, 'timestamp': 1781846764.670702}
# Sent: {'tx_id': 32, 'userId': 101, 'amount': 4637.789434542767, 'timestamp': 1781846766.6717389}
# Sent: {'tx_id': 33, 'userId': 102, 'amount': 13161.967331991991, 'timestamp': 1781846768.6727283}
# Sent: {'tx_id': 34, 'userId': 104, 'amount': 10808.583956504319, 'timestamp': 1781846770.6737134}
# Sent: {'tx_id': 35, 'userId': 101, 'amount': 2054.8430552865384, 'timestamp': 1781846772.6745794}
# Sent: {'tx_id': 36, 'userId': 102, 'amount': 11775.629770620277, 'timestamp': 1781846774.6755316}
# Sent: {'tx_id': 37, 'userId': 102, 'amount': 5552.324992923415, 'timestamp': 1781846776.6789012}
# Sent: {'tx_id': 38, 'userId': 104, 'amount': 11641.678310579535, 'timestamp': 1781846778.679981}
# Sent: {'tx_id': 39, 'userId': 103, 'amount': 14903.521148112603, 'timestamp': 1781846780.6815732}
# Sent: {'tx_id': 40, 'userId': 102, 'amount': 10040.106255226854, 'timestamp': 1781846782.683031}
# Sent: {'tx_id': 41, 'userId': 105, 'amount': 11917.460190075146, 'timestamp': 1781846784.685387}
# Sent: {'tx_id': 42, 'userId': 105, 'amount': 9798.640934838848, 'timestamp': 1781846786.6863475}
# Sent: {'tx_id': 43, 'userId': 105, 'amount': 3900.8223437067977, 'timestamp': 1781846788.6875181}
# Sent: {'tx_id': 44, 'userId': 105, 'amount': 6503.911749349709, 'timestamp': 1781846790.6885192}
# Sent: {'tx_id': 45, 'userId': 101, 'amount': 1746.4127543894513, 'timestamp': 1781846792.6879308}
# Sent: {'tx_id': 46, 'userId': 102, 'amount': 11458.768191404824, 'timestamp': 1781846794.6890922}
# Sent: {'tx_id': 47, 'userId': 102, 'amount': 1807.0185562096876, 'timestamp': 1781846796.6903892}
# Sent: {'tx_id': 48, 'userId': 103, 'amount': 11332.884875059317, 'timestamp': 1781846798.6913729}
# Sent: {'tx_id': 49, 'userId': 102, 'amount': 553.2746418457602, 'timestamp': 1781846800.6922688}
# Sent: {'tx_id': 50, 'userId': 105, 'amount': 2743.1623072397383, 'timestamp': 1781846802.6931226}
# Sent: {'tx_id': 51, 'userId': 101, 'amount': 8984.400420845956, 'timestamp': 1781846804.6942475}
# Sent: {'tx_id': 52, 'userId': 101, 'amount': 14235.491319960798, 'timestamp': 1781846806.695187}
# Sent: {'tx_id': 53, 'userId': 101, 'amount': 2254.742347557028, 'timestamp': 1781846808.696049}
# Sent: {'tx_id': 54, 'userId': 103, 'amount': 14476.258813375809, 'timestamp': 1781846810.6969876}
# Sent: {'tx_id': 55, 'userId': 105, 'amount': 1014.039074286487, 'timestamp': 1781846812.6990244}
# Sent: {'tx_id': 56, 'userId': 105, 'amount': 1620.753172385826, 'timestamp': 1781846814.6999416}
# Sent: {'tx_id': 57, 'userId': 102, 'amount': 3400.002902610277, 'timestamp': 1781846816.7027814}
# Sent: {'tx_id': 58, 'userId': 103, 'amount': 7219.256079226473, 'timestamp': 1781846818.704069}
# Sent: {'tx_id': 59, 'userId': 101, 'amount': 10596.079096965192, 'timestamp': 1781846820.705894}
# Sent: {'tx_id': 60, 'userId': 101, 'amount': 9340.726024385627, 'timestamp': 1781846822.7040205}
# Sent: {'tx_id': 61, 'userId': 103, 'amount': 10347.15653721107, 'timestamp': 1781846824.7048717}
# Sent: {'tx_id': 62, 'userId': 101, 'amount': 9511.56881793501, 'timestamp': 1781846826.707925}
# Sent: {'tx_id': 63, 'userId': 103, 'amount': 4620.758905770043, 'timestamp': 1781846828.708878}
# Sent: {'tx_id': 64, 'userId': 103, 'amount': 1298.7075243030306, 'timestamp': 1781846830.7120385}
# Sent: {'tx_id': 65, 'userId': 104, 'amount': 2116.711785756943, 'timestamp': 1781846832.7128704}
# Sent: {'tx_id': 66, 'userId': 105, 'amount': 3742.917527473607, 'timestamp': 1781846834.7141807}
# Sent: {'tx_id': 67, 'userId': 105, 'amount': 12738.932886394306, 'timestamp': 1781846836.7161329}
# Sent: {'tx_id': 68, 'userId': 102, 'amount': 7168.637322587659, 'timestamp': 1781846838.717264}
# Sent: {'tx_id': 69, 'userId': 101, 'amount': 14697.706250952939, 'timestamp': 1781846840.7185738}
# Sent: {'tx_id': 70, 'userId': 103, 'amount': 12060.36350097329, 'timestamp': 1781846842.7196312}
# Sent: {'tx_id': 71, 'userId': 104, 'amount': 3074.593586106661, 'timestamp': 1781846844.7203748}
# Sent: {'tx_id': 72, 'userId': 105, 'amount': 6807.760804920312, 'timestamp': 1781846846.7212143}
# Sent: {'tx_id': 73, 'userId': 102, 'amount': 2209.0862477410387, 'timestamp': 1781846848.7221844}
# Sent: {'tx_id': 74, 'userId': 102, 'amount': 5410.48122615023, 'timestamp': 1781846850.724265}
# Sent: {'tx_id': 75, 'userId': 103, 'amount': 14206.954857919773, 'timestamp': 1781846852.722258}
# Sent: {'tx_id': 76, 'userId': 102, 'amount': 3747.2248567587503, 'timestamp': 1781846854.7234397}
# Sent: {'tx_id': 77, 'userId': 105, 'amount': 13126.968066110832, 'timestamp': 1781846856.7242126}
# Sent: {'tx_id': 78, 'userId': 105, 'amount': 9225.785749024055, 'timestamp': 1781846858.7251616}
# Sent: {'tx_id': 79, 'userId': 103, 'amount': 8650.973643235766, 'timestamp': 1781846860.7262335}
# Sent: {'tx_id': 80, 'userId': 105, 'amount': 13088.073409446237, 'timestamp': 1781846862.7272308}
# Sent: {'tx_id': 81, 'userId': 101, 'amount': 10114.013729716164, 'timestamp': 1781846864.728263}
# Sent: {'tx_id': 82, 'userId': 101, 'amount': 2454.0795401854093, 'timestamp': 1781846866.729059}
# Sent: {'tx_id': 83, 'userId': 105, 'amount': 9531.543603619331, 'timestamp': 1781846868.7305655}
# Sent: {'tx_id': 84, 'userId': 105, 'amount': 9577.218381429779, 'timestamp': 1781846870.7315822}
# Sent: {'tx_id': 85, 'userId': 101, 'amount': 12145.105340334425, 'timestamp': 1781846872.7325945}
# Sent: {'tx_id': 86, 'userId': 104, 'amount': 13297.530932502097, 'timestamp': 1781846874.7336206}
# Sent: {'tx_id': 87, 'userId': 102, 'amount': 1366.3332423417357, 'timestamp': 1781846876.7347555}
# Sent: {'tx_id': 88, 'userId': 104, 'amount': 13315.708546885826, 'timestamp': 1781846878.736083}
# Sent: {'tx_id': 89, 'userId': 103, 'amount': 8897.487719209987, 'timestamp': 1781846880.737131}
# Sent: {'tx_id': 90, 'userId': 103, 'amount': 2316.1287234554748, 'timestamp': 1781846882.7344217}
# Sent: {'tx_id': 91, 'userId': 101, 'amount': 1895.8638367474057, 'timestamp': 1781846884.7353306}
# Sent: {'tx_id': 92, 'userId': 101, 'amount': 5526.6070803283, 'timestamp': 1781846886.7361064}
# Sent: {'tx_id': 93, 'userId': 104, 'amount': 7090.713145922436, 'timestamp': 1781846888.737305}
# Sent: {'tx_id': 94, 'userId': 103, 'amount': 12756.835273518753, 'timestamp': 1781846890.738188}
# Sent: {'tx_id': 95, 'userId': 105, 'amount': 5019.339950622359, 'timestamp': 1781846892.7395458}
# Sent: {'tx_id': 96, 'userId': 102, 'amount': 8123.129915189941, 'timestamp': 1781846894.7404864}
# Sent: {'tx_id': 97, 'userId': 102, 'amount': 9439.957504341937, 'timestamp': 1781846896.7415905}
# Sent: {'tx_id': 98, 'userId': 103, 'amount': 6606.62500670727, 'timestamp': 1781846898.743115}
# Sent: {'tx_id': 99, 'userId': 101, 'amount': 13817.380421204274, 'timestamp': 1781846900.7438827}
